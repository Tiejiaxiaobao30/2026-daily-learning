# %% [markdown]
# 2026.1.3 Day 3

# %% [markdown]
# 学习内容：列表、循环与判断语句
#
# 接触了列表 就是中括号的形式 里面元素可以混搭
#
# 增.append 删.remove 改 查长度

# %% [markdown]
# 然后是循环语句 注意两点 一是要给变量初始化赋值 二是 变量 += 数值 即 变量 = 变量 + 数值
#
# range（）同样取左不取右 单个对象 是从0开始取 三个对象 第三个为步长

# %% [markdown]
# 最后是判断语句 if elif else

# %% [markdown]
# 下面进入练习：

# %% [markdown]
# 1. 定义一个包含整数的列表 scores，赋值为 [85, 92, 78, 65, 95, 88]。
# 2. 初始化两个变量：excellent_count 用于记录分数大于等于 90 的个数，初始值为 0；total_score 用于累加所有分数，初始值为 0。
# 3. 使用 for 循环遍历 scores 列表中的每一个分数。
# 4. 在循环内部：
#
# a. 将当前分数累加到 total_score 变量上。
#
# b. 使用 if 语句判断当前分数是否大于等于 90。如果是，则将 excellent_count 变量加 1。
#
# 5. 循环结束后，计算平均分 average_score（总分除以分数的个数）。
#
# 6. 使用 f-string 分三行打印出以下信息：
#  优秀分数（>=90）的个数。
#  所有分数的总和。
#  所有分数的平均分（结果包含 3 位小数）。

# %%
scores=[85,92,78,65,95,88]

excellent_count = 0
total_score = 0

for num in scores: 
    total_score += num
    if num >= 90:  
        excellent_count += 1

average_score=total_score/len(scores)

print(f"所有分数的总和:{total_score}")
print(f"优秀分数的个数:{excellent_count}")
print(f"所有分数的平均数:{average_score:.3f}")
# Out:
# 所有分数的总和:503
# 优秀分数的个数:2
# 所有分数的平均数:83.833

# %% [markdown]
# 保留几位小数不仅是n.f 前面：别忘了
#
# 能接「后续多行代码」的语句加冒号，单行干完活的语句不加冒号
#
# 所有「冒号 : 后面的代码」，都必须缩进
